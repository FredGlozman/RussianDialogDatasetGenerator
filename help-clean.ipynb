# %%
with open('items.json', encoding='utf-8') as f:
    lines = f.readlines()

# %%
import json

# %%
lines[3213]
# Out:
# '{"url": "http://otvet.i.ua/user/2477394/6314/", "speakers": ["<p><a href=\\"/user/2477394/\\" class=\\"boy\\"><i></i>Curaki</a></p>", "<p><a href=\\"/user/426537/\\" class=\\"boy\\"><i></i>EVP Limited</a></p>", "<p>\\u0413\\u043e\\u0441\\u0442\\u044c</p>"], "utterances": ["\\u041d\\u0430  \\u044f\\u043a\\u0456\\u0439 \\u043c\\u043e\\u0432\\u0456 \\u043d\\u0430\\u043f\\u0438\\u0441\\u0430\\u043d\\u0438\\u0439 \\u0434\\u0430\\u043d\\u0438\\u0439 \\u0441\\u0430\\u0439\\u0442 ???\\n\\r\\n\\u041c\\u0435\\u043d\\u0435 \\u0446\\u0456\\u043a\\u0430\\u0432\\u0438\\u0442\\u044c \\u043d\\u0430 \\u044f\\u043a\\u0456\\u0439 \\u043c\\u043e\\u0432\\u0456 \\u043d\\u0430\\u043f\\u0438\\u0441\\u0430\\u043d\\u0438\\u0439\\u00a0 \\u0441\\u0430\\u0439\\u0442 i.ua\\u00a0 ???\\u00a0 \\u041c\\u043e\\u0436\\u043b\\u0438\\u0432\\u043e \\u0446\\u0435 javaEE \\u0447\\u0438 \\u043f\\u0440\\u043e\\u0441\\u0442\\u043e php ? \\u0406 \\u044f\\u043a \\u0446\\u0435 \\u043c\\u043e\\u0436\\u043b\\u0438\\u0432\\u043e \\
# ...

# %%
lines[3228]
# Out:
# '{"url": "http://otvet.i.ua/user/2618926/6074/", "speakers": ["<p><a href=\\"/user/2618926/\\" class=\\"girl\\"><i></i>Vivyenn</a></p>", "<p>\\u0413\\u043e\\u0441\\u0442\\u044c</p>", "<p><a href=\\"/user/3393173/\\" class=\\"girl\\"><i></i>\\u0413\\u0430\\u043b\\u0430</a></p>", "<p>\\u0413\\u043e\\u0441\\u0442\\u044c</p>", "<p>\\u0413\\u043e\\u0441\\u0442\\u044c</p>", "<p><a href=\\"/user/2490033/\\" class=\\"girl\\"><i></i>aleksandrinna</a></p>", "<p><a href=\\"/user/1230695/\\" class=\\"girl\\"><i></i>fialk@</a></p>", "<p><a href=\\"/user/98481/\\" class=\\"girl\\"><i></i>\\u041f\\u043e\\u043b\\u043b\\u0438</a></p>", "<p><a href=\\"/user/4219474/\\" class=\\"boy\\"><i></i>RomahaN</a></p>", "<p><a href=\\"/user/1940758/\\" class=\\"boy\\"><i></i>mestor</a></p>", "<p><a href=\\"/user/4416028/\\" class=\\"boy\\"><i></i>Smit*</a></p>"], "utterances": ["\\u041f\\u043e\\u043c\\u043e\\u0433\\u0438\\u0442\\u0435 \\u0441\\u043e\\u0432\\u0435\\u0442\\u043e\\u043c.(\\u0441\\u043c \\u043d\\u04
# ...

# %%
lines[3213] = lines[3213][:-2] + ',\n'

# %%
lines[3228] = lines[3228][:-2] + ',\n'

# %%
with open('items.json', 'w') as f:
    f.writelines(lines)
